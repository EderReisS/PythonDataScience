# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Entrada-de-dados" data-toc-modified-id="Entrada-de-dados-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Entrada de dados</a></span></li><li><span><a href="#Visualização" data-toc-modified-id="Visualização-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Visualização</a></span></li><li><span><a href="#Dados-de-treinamento" data-toc-modified-id="Dados-de-treinamento-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Dados de treinamento</a></span></li><li><span><a href="#K-means-clusters-de-análise-inicial" data-toc-modified-id="K-means-clusters-de-análise-inicial-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>K-means clusters de análise inicial</a></span><ul class="toc-item"><li><span><a href="#Clusters-de-tamanho-n-=-4" data-toc-modified-id="Clusters-de-tamanho-n-=-4-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Clusters de tamanho n = 4</a></span><ul class="toc-item"><li><span><a href="#Definição-do-modelo" data-toc-modified-id="Definição-do-modelo-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Definição do modelo</a></span></li><li><span><a href="#Aplicação-nos-dados" data-toc-modified-id="Aplicação-nos-dados-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Aplicação nos dados</a></span></li><li><span><a href="#Visualização-dos-dados" data-toc-modified-id="Visualização-dos-dados-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Visualização dos dados</a></span></li></ul></li><li><span><a href="#Clusters-de-tamanho-n-=-12" data-toc-modified-id="Clusters-de-tamanho-n-=-12-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Clusters de tamanho n = 12</a></span><ul class="toc-item"><li><span><a href="#Definição-do-modelo" data-toc-modified-id="Definição-do-modelo-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Definição do modelo</a></span></li><li><span><a href="#Aplicação-nos-dados" data-toc-modified-id="Aplicação-nos-dados-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Aplicação nos dados</a></span></li><li><span><a href="#Visualização-dos-dados" data-toc-modified-id="Visualização-dos-dados-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Visualização dos dados</a></span></li></ul></li></ul></li><li><span><a href="#K-mean--de-tamanho-restante" data-toc-modified-id="K-mean--de-tamanho-restante-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>K-mean  de tamanho restante</a></span><ul class="toc-item"><li><span><a href="#Clusters-de-tamanho-n-=-2" data-toc-modified-id="Clusters-de-tamanho-n-=-2-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Clusters de tamanho n = 2</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-3" data-toc-modified-id="Clusters-de-tamanho-n-=-3-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Clusters de tamanho n = 3</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-5" data-toc-modified-id="Clusters-de-tamanho-n-=-5-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Clusters de tamanho n = 5</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-6" data-toc-modified-id="Clusters-de-tamanho-n-=-6-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Clusters de tamanho n = 6</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-7" data-toc-modified-id="Clusters-de-tamanho-n-=-7-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Clusters de tamanho n = 7</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-8" data-toc-modified-id="Clusters-de-tamanho-n-=-8-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Clusters de tamanho n = 8</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-9" data-toc-modified-id="Clusters-de-tamanho-n-=-9-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Clusters de tamanho n = 9</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-10" data-toc-modified-id="Clusters-de-tamanho-n-=-10-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Clusters de tamanho n = 10</a></span></li><li><span><a href="#Clusters-de-tamanho-n-=-11" data-toc-modified-id="Clusters-de-tamanho-n-=-11-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Clusters de tamanho n = 11</a></span></li></ul></li><li><span><a href="#Análise-de-Erro" data-toc-modified-id="Análise-de-Erro-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Análise de Erro</a></span><ul class="toc-item"><li><span><a href="#Definição-os-clusters-na-matriz" data-toc-modified-id="Definição-os-clusters-na-matriz-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Definição os clusters na matriz</a></span></li><li><span><a href="#Definição-de-funções-de-auxílio-de-cálculo" data-toc-modified-id="Definição-de-funções-de-auxílio-de-cálculo-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Definição de funções de auxílio de cálculo</a></span><ul class="toc-item"><li><span><a href="#Distância-euclidiana" data-toc-modified-id="Distância-euclidiana-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Distância euclidiana</a></span></li><li><span><a href="#Custo-por-tamanho-cada-cluster-de-n-centroides" data-toc-modified-id="Custo-por-tamanho-cada-cluster-de-n-centroides-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Custo por tamanho cada cluster de n centroides</a></span></li></ul></li><li><span><a href="#Custo-por-cluster" data-toc-modified-id="Custo-por-cluster-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Custo por cluster</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans

# %% [markdown]
# ## Entrada de dados

# %%
df = pd.read_csv('input_Files/agrupamento.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            X1       X2       X3
# 0     0.27419  0.20583  0.46501
# 1    -0.11294  0.18295  0.10482
# 2     0.07263 -0.00049  0.19415
# 3     0.12657  0.02720  0.07539
# 4     0.08085 -0.14403 -0.19919
# ...       ...      ...      ...
# 3995  0.96504  0.95319  1.13418
# 3996  1.40558  1.03519  0.80022
# 3997  0.71854  0.89610  1.07558
# 3998  0.72128  1.29540  0.95529
# 3999  0.87809  0.99994  0.96010
#
# [4000 rows x 3 columns]>

# %%
centers = pd.read_csv('input_Files/centroides_iniciais.csv')

# %%
centers.describe
# Out:
# <bound method NDFrame.describe of          V1       V2       V3
# 0   0.01076  0.15069  0.04997
# 1   0.91118 -0.01005 -0.09356
# 2  -0.52612  1.04924 -0.13291
# 3   0.60333  1.35328  0.15919
# 4  -0.08450 -0.26050  0.61173
# 5   1.34537  0.20400  1.05071
# 6   0.13437  0.89353  1.05675
# 7   1.01001  0.94161  1.15348
# 8  -0.16753 -0.03010 -0.10393
# 9   0.62507  0.07766  0.31964
# 10  0.19701  1.24595 -0.14311
# 11  0.97439  1.15159 -0.07657
# 12  0.08615 -0.41018  0.93881
# 13  1.08086  0.48531  0.92705
# 14  0.09561  1.16708  0.55425
# 15  0.86545  1.26584  0.86340>

# %% [markdown]
# ## Visualização

# %%
sns.relplot(data = df )

# %%
sns.pairplot(df)

# %% [markdown]
# ## Dados de treinamento

# %%
X = np.array(df)

# %%
X
# Out:
# array([[ 2.74190e-01,  2.05830e-01,  4.65010e-01],
#        [-1.12940e-01,  1.82950e-01,  1.04820e-01],
#        [ 7.26300e-02, -4.90000e-04,  1.94150e-01],
#        ...,
#        [ 7.18540e-01,  8.96100e-01,  1.07558e+00],
#        [ 7.21280e-01,  1.29540e+00,  9.55290e-01],
#        [ 8.78090e-01,  9.99940e-01,  9.60100e-01]])

# %% [markdown]
# ## K-means clusters de análise inicial

# %% [markdown]
# ### Clusters de tamanho n = 4

# %% [markdown]
# #### Definição do modelo

# %%
kmeans_4 = KMeans(n_clusters=4 , random_state=0)

# %%
kmeans_4.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
kmeans_4.labels_
# Out:
# array([0, 2, 2, ..., 3, 3, 3])

# %%
center_4= kmeans_4.cluster_centers_
center_4
# Out:
# array([[ 0.49193264, -0.00487248,  0.9979597 ],
#        [ 1.01286036,  0.49499108,  0.01024166],
#        [-0.01455726,  0.48747319, -0.00493681],
#        [ 0.49145339,  1.00353324,  0.98646925]])

# %% [markdown]
# #### Aplicação nos dados

# %%
df_A4 = df.copy()

# %%
df_A4['CLUSTER']= kmeans_4.labels_

# %% [markdown]
# #### Visualização dos dados

# %%
sns.pairplot(df_A4, hue='CLUSTER', palette ='dark')

# %% [markdown]
# ### Clusters de tamanho n = 12

# %% [markdown]
# #### Definição do modelo

# %%
kmeans_12 = KMeans(n_clusters=12 , random_state=0)

# %%
kmeans_12.fit(X)
# Out:
# KMeans(n_clusters=12, random_state=0)

# %%
kmeans_12.labels_
# Out:
# array([9, 0, 9, ..., 8, 6, 6])

# %%
center_12= kmeans_12.cluster_centers_
center_12
# Out:
# array([[-0.0340424 ,  0.15231732, -0.07047366],
#        [ 0.98544454,  0.01171793,  1.00733695],
#        [-0.01027255,  0.98692323,  1.00366382],
#        [ 0.94340412,  1.14310722,  0.06352165],
#        [ 0.90539431, -0.02801695, -0.13475481],
#        [ 0.00656365, -0.00921431,  0.99146435],
#        [ 0.91534281,  1.06070319,  0.82811519],
#        [-0.00639994,  1.0037755 , -0.01289214],
#        [ 1.05481019,  0.94566396,  1.12836342],
#        [ 0.00937466, -0.15539538,  0.05857813],
#        [ 1.05653543,  0.83886257, -0.07176641],
#        [ 1.1117635 ,  0.02209017,  0.15405212]])

# %% [markdown]
# #### Aplicação nos dados

# %%
df_A12 = df.copy()

# %%
df_A12['CLUSTER']= kmeans_12.labels_

# %% [markdown]
# #### Visualização dos dados

# %%
sns.pairplot(df_A12, hue='CLUSTER', palette='dark')

# %% [markdown]
# ## K-mean  de tamanho restante

# %% [markdown]
# Determinação de outros clusters

# %%
clusterizado = df.copy()

# %% [markdown]
# ### Clusters de tamanho n = 2

# %%
kmeans_2 = KMeans(n_clusters=2 , random_state=0)

# %%
kmeans_2.fit(X)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
center_2= kmeans_2.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 3

# %%
kmeans_3 = KMeans(n_clusters=3 , random_state=0)

# %%
kmeans_3.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
center_3= kmeans_3.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 5

# %%
kmeans_5 = KMeans(n_clusters=5 , random_state=0)

# %%
kmeans_5.fit(X)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
center_5= kmeans_5.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 6

# %%
kmeans_6 = KMeans(n_clusters=6 , random_state=0)

# %%
kmeans_6.fit(X)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
center_6= kmeans_6.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 7

# %%
kmeans_7 = KMeans(n_clusters=7 , random_state=0)

# %%
kmeans_7.fit(X)
# Out:
# KMeans(n_clusters=7, random_state=0)

# %%
center_7= kmeans_7.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 8

# %%
kmeans_8 = KMeans(n_clusters=8 , random_state=0)

# %%
kmeans_8.fit(X)
# Out:
# KMeans(random_state=0)

# %%
center_8= kmeans_8.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 9

# %%
kmeans_9 = KMeans(n_clusters=9 , random_state=0)

# %%
kmeans_9.fit(X)
# Out:
# KMeans(n_clusters=9, random_state=0)

# %%
center_9= kmeans_9.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 10

# %%
kmeans_10 = KMeans(n_clusters=10 , random_state=0)

# %%
kmeans_10.fit(X)
# Out:
# KMeans(n_clusters=10, random_state=0)

# %%
center_10= kmeans_10.cluster_centers_

# %% [markdown]
# ### Clusters de tamanho n = 11

# %%
kmeans_11 = KMeans(n_clusters=11 , random_state=0)

# %%
kmeans_11.fit(X)
# Out:
# KMeans(n_clusters=11, random_state=0)

# %%
center_11= kmeans_11.cluster_centers_

# %% [markdown]
# ## Análise de Erro

# %% [markdown]
# ### Definição os clusters na matriz

# %%
clusterizado['n2'] = kmeans_2.labels_

# %%
clusterizado['n3'] = kmeans_3.labels_

# %%
clusterizado['n4'] = kmeans_4.labels_

# %%
clusterizado['n5'] = kmeans_5.labels_

# %%
clusterizado['n6'] = kmeans_6.labels_

# %%
clusterizado['n7'] = kmeans_7.labels_

# %%
clusterizado['n8'] = kmeans_8.labels_

# %%
clusterizado['n9'] = kmeans_9.labels_

# %%
clusterizado['n10'] = kmeans_10.labels_

# %%
clusterizado['n11'] = kmeans_11.labels_

# %%
clusterizado['n12'] = kmeans_12.labels_

# %%
clusterizado.head()
# Out:
#         X1       X2       X3  n2  n3  n4  n5  n6  n7  n8  n9  n10  n11  n12
# 0  0.27419  0.20583  0.46501   0   0   0   3   5   6   5   1    2    4    9
# 1 -0.11294  0.18295  0.10482   0   0   2   4   5   6   5   1    2    4    0
# 2  0.07263 -0.00049  0.19415   0   0   2   4   5   6   5   1    2    4    9
# 3  0.12657  0.02720  0.07539   0   0   2   4   5   6   5   1    2    4    9
# 4  0.08085 -0.14403 -0.19919   0   0   2   4   5   6   5   1    2    4    9

# %%
centroides = [center_2,center_3,center_4,center_5,center_6,center_7,center_8,center_9,center_10,center_11,center_12]

# %% [markdown]
# ### Definição de funções de auxílio de cálculo

# %%
col = list(clusterizado)

# %% [markdown]
# #### Distância euclidiana

# %%
Cluster_Array=np.array(clusterizado)

# %%
# distância euclidiana
def Dis_Euclidiana( v1, v2):
    distance = np.linalg.norm(v1-v2)
    return distance

# %%
Dis_Euclidiana( Cluster_Array[0][:3], centroides[0][1])
# Out:
# 0.6464266474544133

# %%
clusterizado['aux'] = clusterizado[col[0]]+clusterizado[col[1]]

# %%
col[3:14]
# Out:
# ['n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9', 'n10', 'n11', 'n12']

# %%
centroides
# Out:
# [array([[ 0.50009201,  0.49722385, -0.00363997],
#         [ 0.49307498,  0.50166056,  0.99646183]]),
#  array([[ 0.02093772,  0.49518188, -0.01795224],
#         [ 0.05324471,  0.47714076,  1.01332545],
#         [ 1.01799629,  0.51474322,  0.48310767]]),
#  array([[ 0.49193264, -0.00487248,  0.9979597 ],
#         [ 1.01286036,  0.49499108,  0.01024166],
#         [-0.01455726,  0.48747319, -0.00493681],
#         [ 0.49145339,  1.00353324,  0.98646925]]),
#  array([[ 0.99750732,  0.02348471,  0.02316744],
#         [ 0.02026952,  0.97534386,  0.99410635],
#         [ 1.00139874,  1.01072765,  0.49951267],
#         [ 0.48230755, -0.00715195,  1.00989736],
#         [-0.01916079,  0.48950328, -0.01433696]]),
#  array([[ 0.03010645,  0.9590007 ,  1.02186841],
#         [ 0.97968456,  0.03518661, -0.01967526],
#         [ 1.01134456,  1.0267568 ,  0.48577635],
#         [ 0.01690401,  0.96994061, -0.02590608],
#         [ 0.94991937,  0.05624326,  1.02419847],
# ...

# %% [markdown]
# #### Custo por tamanho cada cluster de n centroides

# %%
def custo( n, cluster, centroides):
    soma=0
    tamanho = cluster.shape[0]
    for i in range(tamanho):
        soma= soma+Dis_Euclidiana( cluster[i][:3], centroides[(n-2)][int(a2[i][n+1])])
    return soma

# %%
custo( 2, Cluster_Array, centroides)
# Out:
# 3050.707876428487

# %% [markdown]
# ### Custo por cluster

# %%
dis = []
for i in range(2,13):
    dis.append(custo( i, Cluster_Array, centroides))
dis
# Out:
# [3050.707876428487,
#  2665.518794632634,
#  2303.0268963796393,
#  2023.9141270481819,
#  1771.5389633171994,
#  1517.9405593672554,
#  1276.860556273519,
#  1254.4087538599388,
#  1230.8664137418298,
#  1210.223640184151,
#  1189.9577292885833]

# %%
C_df = pd.DataFrame({ 'Número de Clusters' : range(2,13,1), 'Função Custo':dis} )
C_df
# Out:
#     Número de Clusters  Função Custo
# 0                    2   3050.707876
# 1                    3   2665.518795
# 2                    4   2303.026896
# 3                    5   2023.914127
# 4                    6   1771.538963
# 5                    7   1517.940559
# 6                    8   1276.860556
# 7                    9   1254.408754
# 8                   10   1230.866414
# 9                   11   1210.223640
# 10                  12   1189.957729

# %%
sns.relplot( data=C_df, x='Número de Clusters', y='Função Custo')

# %% [markdown]
# ## Desafio:
#
# Nesse jogo o usuário irá pensar num número inteiro entre 0 e 100, e vamos desenvolver um programa que adivinhe de forma eficiente o número que o usuário pensou! Fantástico!
#
# O programa deve imprimir uma pergunta:
# `O número que você pensou é: {número}`
# As respostas aceitaveis são `s` ou `n` (sim ou não).  O que fazer se o usuário responder com `si` ou errar e colocar `d` por exemplo?
#
# Caso seja `n` o jogo continua, caso contrário o programa deve imprimir `O número que você pensou é: {número}`
#
# O programa deve perguntar:
# `O número que você pensou é maior ou menor?`
# As respostas aceitaveis são `maior` ou `menor`. Novamente o que fazer caso o usuário cometa um erro tipográfico?

# %%
import random

cont=0
lim_inf=0
lim_sup=100

chute = random.randint(45,75)

certo='s'
errado='n'

#eh_desigualdade = (entrada_I=='maior')or(entrada_I=='menor')# validação para busca do '>' ou '<' inteiro

#eh_valido=(entrada==certo)or(entrada==errado)# validação para vrificação do número pensado


entrada = input(f"Por favor, Digite '{certo}' se o numéro pensado é {chute}, e '{errado}' caso não: ")
eh_valido=(entrada==certo)or(entrada==errado)# validação para vrificação do número pensado

if entrada==certo:
    print(f"{chute} é seu número que você pensou!")
    
else:
    while (not eh_valido):
        print("\n")
        entrada = input(f"Por favor, Digitee '{certo}' se o numéro pensado é {chute}, e '{errado}' caso não: ")
        eh_valido=(entrada==certo)or(entrada==errado)# validação para vrificação do número pensado
        
    if entrada==certo:
        print("\n")
        print(f"{chute} é seu número que você pensou!")
    
    else:
        
        while (not(entrada==certo)and(cont<100)):
            print("\n")
            entrada_I= input(f"O número é maior ou menor que {chute}? (Digite 'maior'/'menor') ")
            eh_desigualdade = (entrada_I=='maior')or(entrada_I=='menor')# validação para busca do '>' ou '<' inteiro

            
            if not(eh_desigualdade):
                print("\n")
                while (not(eh_desigualdade)):
                    entrada_I= input(f"O número é maior ou menor que {chute}? (Digite 'maior'/'menor') ")
                    eh_desigualdade = (entrada_I=='maior')or(entrada_I=='menor')# validação para busca do '>' ou '<' inteiro

                    
            if entrada_I=='maior':
                lim_inf=chute+1
                
            else:
                lim_sup=chute-1
                
            chute=random.randint(lim_inf,lim_sup)
            
            print("\n")            
            entrada = input(f"Por favor, Digite '{certo}' se o numéro pensado é {chute}, e '{errado}' caso não: ")
            eh_valido=(entrada==certo)or(entrada==errado)# validação para vrificação do número pensado
            
            if not(eh_valido):
                while (not(eh_valido)):
                    print("\n")
                    entrada = input(f"Por favor, Digite '{certo}' se o numéro pensado é {chute}, e '{errado}' caso não: ")
                    eh_valido=(entrada==certo)or(entrada==errado)# validação para vrificação do número pensado
            else:
                cont=cont+1
                
        print("\n")                
        print(f"{chute} é seu número que você pensou!")
# Out:
# Por favor, Digite 's' se o numéro pensado é 48, e 'n' caso não: n
#
#
# O número é maior ou menor que 48? (Digite 'maior'/'menor') menor
#
#
# Por favor, Digite 's' se o numéro pensado é 24, e 'n' caso não: maior
#
#
# Por favor, Digite 's' se o numéro pensado é 24, e 'n' caso não: n
#
#
# O número é maior ou menor que 24? (Digite 'maior'/'menor') maior
#
#
# Por favor, Digite 's' se o numéro pensado é 39, e 'n' caso não: n
#
#
# O número é maior ou menor que 39? (Digite 'maior'/'menor') menor
#
#
# Por favor, Digite 's' se o numéro pensado é 30, e 'n' caso não: n
#
#
# O número é maior ou menor que 30? (Digite 'maior'/'menor') maior
#
#
# Por favor, Digite 's' se o numéro pensado é 37, e 'n' caso não: n
#
#
# O número é maior ou menor que 37? (Digite 'maior'/'menor') menor
#
#
# Por favor, Digite 's' se o numéro pensado é 35, e 'n' caso não: n
#
#
# O número é maior ou menor que 35? (Digite 'maior'/'menor') menor
#
#
# ...

# %%
# Out:
# error: pathspec '–m' did not match any file(s) known to git
# error: pathspec '“trabalho' did not match any file(s) known to git
# error: pathspec 'de' did not match any file(s) known to git
# error: pathspec 'aula' did not match any file(s) known to git
# error: pathspec 'lets' did not match any file(s) known to git
# error: pathspec 'code”' did not match any file(s) known to git
